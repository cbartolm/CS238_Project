# %% [markdown]
# ### Import Libraries

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

import numpy as np
import pandas as pd
import seaborn as sns

from matplotlib import style
style.use('ggplot')

# %% [markdown]
# ### Bumper Baseline

# %%
bumper_standard = pd.read_csv("./results/baseline_bumper.csv")
plt.figure(1, figsize=(8,6))

plt.plot(bumper_standard.iloc[:,0],bumper_standard.iloc[:,1])
plt.title("Total Reward of the different experiments for the bumper baseline")
plt.ylabel("Total Reward")
plt.xlabel("Experience number")

# Plot mean value
mean_value = np.mean(bumper_standard.iloc[:,1])
plt.axhline(y=mean_value, xmin=0, xmax=1, linewidth=0.5, color = 'g')

plt.savefig('bumper_curve.png')

# %%
## v_noise_coefficient plots

y = [-13.94, -13.94, -13.94]
yerr = 2.126

plt.figure(2, figsize=(11,8))
plt.errorbar(x = [0.2, 2, 8], y = y, yerr = yerr, fmt='--o')
plt.xlabel("v_noise")
plt.ylabel("Mean Total Reward and its error")

plt.savefig('bumper_v_noise.png')

# %%
## om_noise_coefficient plots

y = [-13.94, -13.94, -13.94]
yerr = 2.126

plt.figure(3, figsize=(11,8))
plt.errorbar(x = [0.2, 0.5, 2.5], y = y, yerr = yerr, fmt='--o')
plt.xlabel("om_noise")
plt.ylabel("Mean Total Reward and its error")

plt.savefig('bumper_om_noise.png')

# %% [markdown]
# ### Lidar Baseline

# %%
lidar_standard = pd.read_csv("./results/baseline_lidar.csv")
plt.figure(4, figsize=(8,6))

plt.plot(lidar_standard.iloc[:,0],lidar_standard.iloc[:,1])
plt.title("Total Reward of the different experiments for the Lidar baseline")
plt.ylabel("Total Reward")
plt.xlabel("Experience number")

# Plot mean value
mean_value = np.mean(lidar_standard.iloc[:,1])
plt.axhline(y=mean_value, xmin=0, xmax=1, linewidth=0.5, color = 'g')

plt.savefig('lidar_curve.png')

# %%
## v_noise_coefficient plots

y = [-7.900, -5.827, -3.827]
yerr = [2.415, 2.205, 2.067]

plt.figure(5, figsize=(11,8))
plt.errorbar(x = [0.5, 2, 8], y = y, yerr = yerr, fmt='--o')
plt.xlabel("v_noise")
plt.ylabel("Mean Total Reward and its error")

plt.savefig('lidar_v_noise.png')

# %%
## om_noise_coefficient plots

y = [-6.793, -5.827, -10.730]
yerr = [2.098, 2.205, 2.392]

plt.figure(6, figsize=(11,8))
plt.errorbar(x = [0.1, 0.5, 2.5], y = y, yerr = yerr, fmt='--o')
plt.xlabel("om_noise")
plt.ylabel("Mean Total Reward and its error")

plt.savefig('lidar_om_noise.png')

# %% [markdown]
# ### Final Model

# %%
final_standard = pd.read_csv("./results/final_method.csv")
plt.figure(7, figsize=(8,6))

plt.plot(final_standard.iloc[:,0],final_standard.iloc[:,1])
plt.title("Total Reward of the different experiments for final model")
plt.ylabel("Total Reward")
plt.xlabel("Experience number")

# Plot mean value
mean_value = np.mean(lidar_standard.iloc[:,1])
plt.axhline(y=mean_value, xmin=0, xmax=1, linewidth=0.5, color = 'g')

plt.savefig('final_model_curve.png')
